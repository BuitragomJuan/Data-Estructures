# %% [markdown]
# <a href="https://colab.research.google.com/github/BuitragomJuan/Data-Estructures/blob/main/analisis2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Parte 2 Proyecto Final**
# *   Alanis Nicole Forero Salas
# *   Kevin Jaimes Carrillo
# *   Juan Buitrago

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import RFE

# %%
train_data = pd.read_csv('entrenamiento.csv')

# %%
validation_data = pd.read_csv('prueba.csv')

# %% [markdown]
# Cargar datos

# %%
train_data.head()
# Out:
#                                       RowId  YearStart  YearEnd LocationAbbr  \
# 0   BRFSS~2017~2017~66~Q35~TOC03~AGE~GENDER       2017     2017           GU
# 1     BRFSS~2015~2015~56~Q31~TCC02~AGE~RACE       2015     2015           WY
# 2     BRFSS~2016~2016~26~Q10~TSC10~AGE~RACE       2016     2016           MI
# 3     BRFSS~2018~2018~44~Q33~TOC08~AGE~RACE       2018     2018           RI
# 4  BRFSS~2017~2017~37~Q09~TSC09~AGE~OVERALL       2017     2017           NC
#
#      LocationDesc Datasource                    Class  \
# 0            Guam      BRFSS           Overall Health
# 1         Wyoming      BRFSS        Cognitive Decline
# 2        Michigan      BRFSS  Screenings and Vaccines
# 3    Rhode Island      BRFSS           Overall Health
# 4  North Carolina      BRFSS  Screenings and Vaccines
#
#                                                Topic  \
# 0          Recent activity limitations in past month
# 1  Functional difficulties associated with subjec...
# 2  Up-to-date with recommended vaccines and scree...
# 3       Self-rated health (good to excellent health)
# 4                      Ever had pneumococcal vaccine
#
#                                             Question Data_Value_Unit  ...  \
# 0  Mean number of days with activity limitations ...          Number  ...
# 1  Percentage of older adults who reported subjec...               %  ...
# 2  Percentage of older adult men who are up to da...               %  ...
# 3  Percentage of older adults who self-reported t...               %  ...
# 4  Percentage of at risk adults (have diabetes, a...               %  ...
#
#   TopicID QuestionID  LocationID  StratificationCategoryID1 StratificationID1  \
# 0   TOC03        Q35          66                        AGE              5064
# 1   TCC02        Q31          56                        AGE       AGE_OVERALL
# 2   TSC10        Q10          26                        AGE            65PLUS
# 3   TOC08        Q33          44                        AGE       AGE_OVERALL
# 4   TSC09        Q09          37                        AGE              5064
#
#   StratificationCategoryID2  StratificationID2  Z_Score_Data_Value  \
# 0                    GENDER               MALE           -1.366986
# 1                      RACE                HIS           -0.162763
# 2                      RACE                BLK           -0.848834
# 3                      RACE                BLK            1.406085
# 4                   OVERALL            OVERALL            0.384175
#
#   Data_Value_Capped LocationDesc_encoded
# 0               7.2                   11
# 1              32.3                   58
# 2              18.0                   23
# 3              65.0                   43
# 4              43.7                   35
#
# [5 rows x 34 columns]

# %%
validation_data.head()
# Out:
#                                      RowId  YearStart  YearEnd LocationAbbr  \
# 0    BRFSS~2017~2017~48~Q32~TOC07~AGE~RACE       2017     2017           TX
# 1    BRFSS~2015~2015~16~Q37~TGC02~AGE~RACE       2015     2015           ID
# 2    BRFSS~2015~2015~26~Q22~TSC07~AGE~RACE       2015     2015           MI
# 3  BRFSS~2018~2018~34~Q08~TOC01~AGE~GENDER       2018     2018           NJ
# 4  BRFSS~2015~2015~09~Q45~TOC13~AGE~GENDER       2015     2015           CT
#
#   LocationDesc Datasource                    Class  \
# 0        Texas      BRFSS           Overall Health
# 1        Idaho      BRFSS               Caregiving
# 2     Michigan      BRFSS  Screenings and Vaccines
# 3   New Jersey      BRFSS           Overall Health
# 4  Connecticut      BRFSS           Overall Health
#
#                                                Topic  \
# 0            Self-rated health (fair to poor health)
# 1  Expect to provide care for someone in the next...
# 2                           High blood pressure ever
# 3    Physically unhealthy days (mean number of days)
# 4  Fair or poor health among older adults with ar...
#
#                                             Question Data_Value_Unit  ...  \
# 0  Percentage of older adults who self-reported t...               %  ...
# 1  Percentage of older adults currently not provi...               %  ...
# 2  Percentage of older adults who have ever been ...               %  ...
# 3  Physically unhealthy days (mean number of days...          Number  ...
# 4  Fair or poor health among older adults with do...               %  ...
#
#   TopicID QuestionID  LocationID  StratificationCategoryID1 StratificationID1  \
# 0   TOC07        Q32          48                        AGE              5064
# 1   TGC02        Q37          16                        AGE              5064
# 2   TSC07        Q22          26                        AGE              5064
# 3   TOC01        Q08          34                        AGE            65PLUS
# 4   TOC13        Q45           9                        AGE            65PLUS
#
#   StratificationCategoryID2  StratificationID2  Z_Score_Data_Value  \
# 0                      RACE                BLK           -0.503400
# 1                      RACE                BLK           -0.162763
# 2                      RACE                BLK            1.338918
# 3                    GENDER               MALE           -1.520513
# 4                    GENDER             FEMALE           -0.321087
#
#   Data_Value_Capped LocationDesc_encoded
# 0              25.2                   48
# 1              32.3                   13
# 2              63.6                   23
# 3               4.0                   32
# 4              29.0                    6
#
# [5 rows x 34 columns]

# %%
entrenamiento_adicional, validacion = train_test_split(train_data, test_size=0.2, random_state=42)

# %% [markdown]
# Train2

# %%
# Obtener las columnas categóricas excluyendo la columna "class"
columnas_categoricas = [col for col in entrenamiento_adicional.columns if col != 'Class' and entrenamiento_adicional[col].dtype == 'object']

# Obtener las columnas numéricas
columnas_numericas = [col for col in entrenamiento_adicional.columns if col != 'Class' and entrenamiento_adicional[col].dtype != 'object']

# Realizar la codificación one-hot en las columnas categóricas solamente
entrenamiento_adicional_encoded = pd.get_dummies(entrenamiento_adicional, columns=columnas_categoricas, drop_first=True)

# Mantener las columnas numéricas y la columna "class" sin cambios
entrenamiento_adicional_encoded[columnas_numericas] = entrenamiento_adicional[columnas_numericas]
entrenamiento_adicional_encoded['Class'] = entrenamiento_adicional['Class']

# Aplicar el mismo proceso a los datos de validación
validacion_encoded = pd.get_dummies(validacion, columns=columnas_categoricas, drop_first=True)
validacion_encoded[columnas_numericas] = validacion[columnas_numericas]
validacion_encoded['Class'] = validacion['Class']

# %%
entrenamiento_adicional_encoded.head()
# Out:
#         YearStart  YearEnd              Class  Data_Value  Data_Value_Alt  \
# 163761       2021     2021         Caregiving        32.3            32.3
# 97931        2020     2020  Cognitive Decline        28.5            28.5
# 85900        2015     2015     Overall Health         5.9             5.9
# 168227       2017     2017     Overall Health        89.0            89.0
# 143976       2016     2016     Overall Health        32.3            32.3
#
#         Low_Confidence_Limit  High_Confidence_Limit  LocationID  \
# 163761                  26.5                   38.3          40
# 97931                   19.5                   39.6          15
# 85900                    5.3                    6.6          25
# 168227                  86.6                   91.0          22
# 143976                  26.5                   38.3          28
#
#         Z_Score_Data_Value  Data_Value_Capped  ...  \
# 163761           -0.162763              32.30  ...
# 97931            -0.345076              28.50  ...
# 85900            -1.429356               5.90  ...
# 168227            2.557534              68.15  ...
# 143976           -0.162763              32.30  ...
#
#         StratificationID1_AGE_OVERALL  StratificationCategoryID2_OVERALL  \
# 163761                          False                              False
# 97931                            True                              False
# 85900                            True                              False
# 168227                           True                              False
# 143976                          False                              False
#
#         StratificationCategoryID2_RACE  StratificationID2_BLK  \
# 163761                            True                   True
# 97931                            False                  False
# 85900                            False                  False
# 168227                            True                  False
# 143976                            True                  False
#
#         StratificationID2_FEMALE  StratificationID2_HIS  \
# 163761                     False                  False
# 97931                      False                  False
# 85900                       True                  False
# 168227                     False                  False
# 143976                     False                   True
#
#         StratificationID2_MALE  StratificationID2_NAA  \
# 163761                   False                  False
# 97931                     True                  False
# 85900                    False                  False
# 168227                   False                  False
# 143976                   False                  False
#
#         StratificationID2_OVERALL  StratificationID2_WHT
# 163761                      False                  False
# 97931                       False                  False
# 85900                       False                  False
# 168227                      False                   True
# 143976                      False                  False
#
# [5 rows x 31505 columns]

# %% [markdown]
# **ARBOL DE DECISION**

# %% [markdown]
# Por medio del arbol de decisión podemos saber que características se utilizan mas en las divisiones del arbol para saber que variables es mas pertinente eliminar.

# %%
# Definir modelo de árbol de decisión
arbol_decision = DecisionTreeClassifier()

# Inicializar el selector de características
rfe = RFE(arbol_decision, n_features_to_select=2)  # Seleccionar cinco caracteristicas

x_train = entrenamiento_adicional_encoded.drop("Class", axis=1)  # separacion para datos de entrenamiento
y_train = entrenamiento_adicional_encoded["Class"]

X_validation = validacion_encoded.drop("Class", axis=1)  # separacion para datos de test
y_validation = validacion_encoded["Class"]

# %%
# Ajustar el selector de características a los datos
rfe.fit(x_train, y_train)

# Seleccionar las características
caracteristicas_seleccionadas = rfe.support_

# Eliminar las características no seleccionadas
x_train_seleccionado = x_train[:,caracteristicas_seleccionadas]
x_test_seleccionado = X_validation[:,caracteristicas_seleccionadas]
